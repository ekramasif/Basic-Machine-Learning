# %% [markdown]
# <a href="https://colab.research.google.com/github/ekramasif/Basic-Machine-Learning/blob/main/Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Linear Regression

# %% [markdown]
# ## Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing the dataset

# %% [markdown]
# ### Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset=pd.read_csv('/content/drive/MyDrive/Datasets/50_Startups.csv')
dataset.head(10)
# Out:
#    R&D Spend  Administration  Marketing Spend       State     Profit
# 0  165349.20       136897.80        471784.10    New York  192261.83
# 1  162597.70       151377.59        443898.53  California  191792.06
# 2  153441.51       101145.55        407934.54     Florida  191050.39
# 3  144372.41       118671.85        383199.62    New York  182901.99
# 4  142107.34        91391.77        366168.42     Florida  166187.94
# 5  131876.90        99814.71        362861.36    New York  156991.12
# 6  134615.46       147198.87        127716.82  California  156122.51
# 7  130298.13       145530.06        323876.68     Florida  155752.60
# 8  120542.52       148718.95        311613.29    New York  152211.77
# 9  123334.88       108679.17        304981.62  California  149759.96

# %%
sns.set_theme(style="darkgrid")
sns.set_context('paper', font_scale=1.4)
sns.distplot(dataset['Profit'] , kde=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
X = dataset.iloc[:, 2].values
y = dataset.iloc[:,-1].values
print(X)
# Out:
# [471784.1  443898.53 407934.54 383199.62 366168.42 362861.36 127716.82
#  323876.68 311613.29 304981.62 229160.95 249744.55 249839.44 252664.93
#  256512.92 261776.23 264346.06 282574.31 294919.57      0.   298664.47
#  299737.29 303319.26 304768.73 140574.81 137962.62 134050.07 353183.81
#  118148.2  107138.38  91131.24  88218.23  46085.25 214634.81 210797.67
#  205517.64 201126.82 197029.42 185265.1  174999.3  172795.67 164470.71
#  148001.11  35534.17  28334.72   1903.93 297114.46      0.        0.
#   45173.06]

# %%
print(y)
# Out:
# [192261.83 191792.06 191050.39 182901.99 166187.94 156991.12 156122.51
#  155752.6  152211.77 149759.96 146121.95 144259.4  141585.52 134307.35
#  132602.65 129917.04 126992.93 125370.37 124266.9  122776.86 118474.03
#  111313.02 110352.25 108733.99 108552.04 107404.34 105733.54 105008.31
#  103282.38 101004.64  99937.59  97483.56  97427.84  96778.92  96712.8
#   96479.51  90708.19  89949.14  81229.06  81005.76  78239.91  77798.83
#   71498.49  69758.98  65200.33  64926.08  49490.75  42559.73  35673.41
#   14681.4 ]

# %% [markdown]
# ## Taking care of missing data

# %% [markdown]
# ## Encoding categorical data

# %% [markdown]
# ### Encoding the Independent Variable

# %% [markdown]
# ### Encoding the Dependent Variable

# %% [markdown]
# ## Splitting the dataset into the Training set and Test set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 4)
print(X_train)
# Out:
# [303319.26 118148.2  214634.81 261776.23 264346.06 353183.81 197029.42
#  298664.47 140574.81      0.   252664.93 229160.95      0.   107138.38
#  148001.11   1903.93 134050.07  46085.25 282574.31  28334.72 210797.67
#  256512.92 407934.54  35534.17 205517.64 299737.29 471784.1  383199.62
#  185265.1  201126.82  45173.06  91131.24 174999.3  304981.62 311613.29
#  304768.73 172795.67 443898.53 362861.36 297114.46]

# %% [markdown]
# ## Feature Scaling

# %% [markdown]
# ## Training the Linear regression model with the training data

# %%
X_train.ndim
# Out:
# 1

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
#X_train = reshape((1,1))
regressor.fit(X_train.reshape(-1,1), y_train.reshape(-1,1))
# Out:
# LinearRegression()

# %%
# p = X_train.reshape(-1,1)
# p.shape

# %% [markdown]
# ## Predict test set result

# %%
y_pred = regressor.predict(X_test.reshape(-1,1))

# %%
y_pred
# Out:
# array([[ 89054.4209904 ],
#        [ 58164.72985833],
#        [118568.14431399],
#        [146726.51362431],
#        [118591.09448446],
#        [ 79501.26076255],
#        [136497.79992757],
#        [ 91532.47828466],
#        [ 97943.74590471],
#        [129494.21039271]])

# %% [markdown]
# ##Making the Confusion Matrix

# %% [markdown]
# ## Visualise the training set result

# %%
'''R&D Spend vs Profit'''
# plt.scatter(X_train, y_train, marker='*',color='red')
# plt.plot(X_train, regressor.predict(X_train.reshape(-1,1)), color='blue' )
# plt.title('R&D Spend vs Profit (Training set)')
# plt.xlabel('R&D Spend')
# plt.ylabel('Profit')
# plt.show()

# %%
'''Administration vs Profit'''

# plt.scatter(X_train, y_train, marker='*',color='red')
# plt.plot(X_train, regressor.predict(X_train.reshape(-1,1)), color='blue' )
# plt.title('Administration vs Profit (Training set)')
# plt.xlabel('Administration')
# plt.ylabel('Profit')
# plt.show()

# %%
'''Marketing Spend vs Profit (Training set)'''

plt.scatter(X_train, y_train, marker='*',color='red')
plt.plot(X_train, regressor.predict(X_train.reshape(-1,1)), color='blue' )
plt.title('Marketing Spend vs Profit (Training set)')
plt.xlabel('Marketing Spend')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ## Visualise the test set result

# %%
'''R&D Spend vs Profit'''

# plt.scatter(X_train, y_train, marker='*', color='g')
# plt.scatter(X_test, y_test, marker='*', color='blue')
# plt.plot(X_test, regressor.predict(X_test.reshape(-1,1)), color = 'red')
# plt.title('R&D Spend vs Profit (Training set)')
# plt.xlabel('R&D Spend')
# plt.ylabel('Profit')
# plt.show()

# %%
'''Administration vs Profit'''

# plt.scatter(X_train, y_train, marker='*', color='g')
# plt.scatter(X_test, y_test, marker='*', color='blue')
# plt.plot(X_test, regressor.predict(X_test.reshape(-1,1)), color = 'red')
# plt.title('Administration vs Profit (Training set)')
# plt.xlabel('Administration')
# plt.ylabel('Profit')
# plt.show()

# %%
'''Marketing Spend vs Profit'''

plt.scatter(X_train, y_train, marker='*', color='g')
plt.scatter(X_test, y_test, marker='*', color='blue')
plt.plot(X_test, regressor.predict(X_test.reshape(-1,1)), color = 'red')
plt.title('Marketing Spend vs Profit (Training set)')
plt.xlabel('Marketing Spend')
plt.ylabel('Profit')
plt.show()

# %% [markdown]
# ## Seaborn

# %%
sns.regplot(x = "R&D Spend", y = "Profit",  marker='*', color="#4CB391",  data=dataset).set(title='R&D Spend vs Profit (Training set)')
# Out:
# [Text(0.5, 1.0, 'R&D Spend vs Profit (Training set)')]

# %%
'''Administration vs Profit'''

sns.regplot(x = "Administration", y = "Profit",  marker='*', color="#4CB391",  data=dataset).set(title='Administration vs Profit')
# Out:
# [Text(0.5, 1.0, 'Administration vs Profit')]

# %%
'''Marketing Spend vs Profit'''

sns.regplot(x = "Marketing Spend", y = "Profit",  marker='*', color="#4CB391",  data=dataset).set(title='Marketing Spend vs Profit')
# Out:
# [Text(0.5, 1.0, 'Marketing Spend vs Profit')]

# %%
'''R&D Spend vs Profit'''

sns.lmplot(x="R&D Spend", y="Profit", data=dataset, height=8,  aspect=1).set(title='R&D Spend vs Profit (Training set)')

# %%
'''Administration vs Profit'''

sns.lmplot(x="Administration", y="Profit", data=dataset, height=8,  aspect=1).set(title='Administration vs Profit (Training set)')

# %%
'''Marketing Spend vs Profit'''

sns.lmplot(x="Marketing Spend", y="Profit", data=dataset, height=8,  aspect=1).set(title='Marketing Spend vs Profit (Training set)')
